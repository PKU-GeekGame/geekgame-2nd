# %%
import numpy as np
import json

# %%
res=np.zeros((250,11),int)
with open("challenge.har",'r') as fp:
    res_dict=json.load(fp)

# %%
for i in res_dict:
    n=int(i)
    res[n//11,n%11]=1

# %%
# flag{ShouldBeSponsoredByTencent}

# %%
for i in range(250):
    ss=""
    for j in range(10):
        if res[i,j]==1:
            ss=ss+"x"*5
        else:
            ss=ss+" "*5
    
    print(ss)
# Out:
# xxxxx
#
#           xxxxxxxxxxxxxxx
#      xxxxxxxxxx     xxxxxxxxxx
#      xxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxx
#      xxxxxxxxxx
#      xxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxx
#
#      xxxxxxxxxxxxxxx
#           xxxxxxxxxx
#           xxxxxxxxxx
#           xxxxxxxxxx
#           xxxxxxxxxx
#           xxxxxxxxxx
#      xxxxxxxxxxxxxxxxxxxx
#
#      xxxxxxxxxxxxxxxxxxxx
#                     xxxxxxxxxx
#      xxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxx          xxxxxxxxxx
#      xxxxxxxxxxxxxxx     xxxxxxxxxx
#
#      xxxxxxxxxxxxxxx     xxxxxxxxxx
# xxxxxxxxxx          xxxxxxxxxx
# xxxxxxxxxx          xxxxxxxxxx
#      xxxxxxxxxxxxxxxxxxxxxxxxx
#                     xxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxx
#
#                xxxxxxxxxxxxxxx
#           xxxxxxxxxx
#           xxxxxxxxxx
# xxxxxxxxxxxxxxx
#           xxxxxxxxxx
#           xxxxxxxxxx
#                xxxxxxxxxxxxxxx
#
#      xxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxx          xxxxxxxxxx
# xxxxxxxxxxxxxxx
#      xxxxxxxxxxxxxxx
# ...
